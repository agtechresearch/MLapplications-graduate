# %% [markdown]
# # **0. 구글 코랩(Colab)?**
# ## ▶ 구글에서 제공하는 주피터노트북(Jupyter Notebook)
# ## ▶ 구글의 가상서버를 이용(사용자의 컴퓨터 성능에 영향을 받지 않음)
# ## ▶ 데이터 저장공간과 GPU 제공
# * 코랩 구조(Jupyter notebook과 동일)
# > * 코드 셀(Code cell) : 프로그래밍 코드를 작성하는 공간
# > * 텍스트 셀(Markdown cell) : 프로그래밍 코드 외 설명을 위한 텍스트, 그림, 표 등을 넣는 공간, 프로그램에 영향을 주지 않음
# ## ▶ 코랩 실행방법
# * 구글 드라이브 접속 -> 새로만들기 -> 더보기 -> Colabotory
# * 혹은 다음 주소를 통한 직접 접속 https://colab.research.google.com

# %% [markdown]
# ![슬라이드1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![슬라이드2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![슬라이드3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # **1. 코랩의 간단 기능**
#
# ## ▶ 실행과 출력
# * 셀: 실행의 단위
# * 재생 버튼을 눌러서 셀 실행
#     1. 셀을 실행하고 커서가 다음 칸으로 넘어감: shift + enter
#     2. 셀을 실행하고 커서가 해당 셀에 있음: ctrl + enter
#
# * 출력은 맨 마지막 값을 출력
# ```
# a = 2
# b = 3
# a+b
# a-b
# ```
#
# ## ▶ 세션 저장소 및 구글드라이브 연동
# * 세션저장소 : 현재 연결된 런타임 동안만 유효한 **일시적인 저장공간**
# * 로그인된 계정의 구글드라이브와 연동할 경우 정보저장 및 계속 보관 가능
#
# ## ▶ 마크다운
# * 텍스트 셀 내에서 다양한 형태의 글꼴을 작성하게 하는 문법
#
# ## ▶ 다양한 설정 기능
# * 도구 -> 설정
#
# ## ▶ 간단한 사용 방법
# * Enter : 줄내림
# * 파일 -> 저장 : 파일 저장(Ctrl + S)

# %% [markdown]
# ## ❓ 업로드한 파일 및 새로만든 폴더가 보이지 않는 경우 파일목록 새로고침
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. 기초 파이썬 문법 복습**

# %% [markdown]
# ##  1. 파이썬 구조
#
# ▶ **표현식 - 문장 - 프로그램** <br>
# > **표현식 (Expression)** : 파이썬에서 어떠한 값을 만들어내는 간단한 코드 <br>
# >
# > **문장 (Statement)** : 표현식이 하나이상 모인 경우, 그 자체로 어떠한 값을 만들어낼 수
# > 없으면 문장이 아님
# >
# > **프로그램 (Program)** : 문장이 모여서 형성된 것
# >
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ▶ **변수명명 규칙과 예약어**
# > * **변수 (variable)** : 어떠한 값을 저장하는 메모리 공간(그릇)
# >
# >   * 변수 이름 = 값
# >   * 대입연산자(=)를 이용하여 변수에 값 할당
# >
# > * **변수명 규칙**
# >> 문자, 숫자, _(언더바)포함 가능, 하지만 **숫자로 시작하는것은 안된다.**
# >>
# >> 공백이나 다른 특수문자는 사용할 수 없다. ex) _python^^
# >>
# >> 대 소문자 구분 (myVar와 MyVar는 다른 변수) <br>
# >>
# >>
# >> **예약어**는 변수명으로 사용하면 안된다. <br>
# >> * **파이썬의 예약어 (reserved words)** <br>
# >> True, False, None, and, or, not, break, continue, return, if, else, elif, for, while, except, finally, global, import, try 등 <br>
# >>
# >> 대표적인 영문 명명방식(Naming convention)
# >> * **Camel case** <br>
# >> 단어사이에 공백없이, 낙타의 등모양처럼 뒤에 **연결되는 단어의 첫 글자를 대문자** 표기 <br>
# >> 예시 : myVar, outputList, myBioStat
# >>
# >> * **Snake case** <br>
# >> 단어사이에 **공백을 언더바(_)로 표기하여 연결**하는 방식 <br>
# >> 예시 : my_var, output_list, my_bio_stat
# >

# %%
# 직접해보기1 - 내가 만든 변수에 숫자 3 넣기
first_number = 3

# %% [markdown]
# ▶ **기본 데이터형**
# > **숫자형** (int, float)  <br>
# > : 정수형(1, 10, 123), 실수형(0.5, 0.1234, 123.456)
# >
# > **불형** (Boolean => bool) <br>
# > : True, False
# >
# > **문자열** (string => str) <br>
# > : "알고리즘 수업 파이팅"
# > : '오늘은 화요일'
# > : "2024"
# >
# +  type()을 사용하면 데이터의 자료형을 알 수 있다

# %%
student = "2100345"

type(student)
# Out:
# str

# %%
type("머신러닝 수업 파이팅")
# Out:
# str

# %%
type("2024")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
# 문자열 내부의 문자열
print("산불 재난 경보 '주의' 단계‥곳곳 야산 화재 잇따라")
# Out:
# 산불 재난 경보 '주의' 단계‥곳곳 야산 화재 잇따라

# %% [markdown]
# ▶ 자료형의 타입 변환
#
# * int(  )
#
# * float(   )
#
# * str(   )
#
# ↪ 변환하고 싶은 값이나 변수를 넣으면 변환됨

# %%
# 정수를 실수로 변환하기
a = 67
print(type(a))
print(float(a))
# Out:
# <class 'int'>
# 67.0

# %%
# 정수를 문자열로 변환하기
str(a)
# Out:
# '67'

# %% [markdown]
# ▶ **산술 연산자**
# > **더하기(+), 빼기(-), 곱하기(*), 나누기(/, //, %)**
# >
# > 대입연산자와 조합하여 사용하기도 함
# >
# > ![image.png](data:image/png;base64,...)

# %%
# a,b에 정수형 데이터 할당

a = 5
b = 3

# 각종 연산하기

print('a+b: ',a + b)
print('a/b: ',a / b)  # 기본 나눗셈
print('a//b: ',a // b) # 몫
print('a%b: ' ,a % b)  # 나머지
print('a**b: ',a ** b) # 제곱
# Out:
# a+b:  8
# a/b:  1.6666666666666667
# a//b:  1
# a%b:  2
# a**b:  125

# %%
# 직접해보기2 - 두 숫자를 곱해서 결과가 6이 나오게 하기
a = '2'
b = 3

# %%
int(a) * b
# Out:
# 6

# %%
# 문자열 연산(1)
fruit = '사과'
I_want = '3개'

print(fruit+' '+I_want, '주세요')
# Out:
# 사과 3개 주세요

# %%
# 문자열 연산(2)
fruit = '사과'
print(fruit * 3)
# Out:
# 사과사과사과

# %% [markdown]
# ▶ **관계 연산자**
# > 어떤것이 크거나 작지않은지 **비교하는 것**
# >
# > 주로 조건문(if)이나 반복문(while)에서 사용, 단독으로는 거의 사용하지 않음
# >
# > 결과는 bool형 값(True, False)
# >
# > ![image.png](data:image/png;base64,...)

# %%
# 관계 연산자 예시

a = 99

print(a > 100)
print(a <= 200)
print(a == 99)
print(a != 100)
# Out:
# False
# True
# True
# True

# %% [markdown]
# ▶ **논리 연산자**
# > **and(그리고), or(또는), not(부정) 세가지** 종류
# >
# > 결과로 True 혹은 False
# >
# > 예시: (a>100) and (a<200) a는 100과 200 사이에 들어있어야 찬다(참)
# >
# >![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. 출력 (print 함수)
#  ▶ 출력 하고싶은 **값들을 ()안에 나열하여 결과 값으로 출력** <br>
#  ▶ print(값) <br>
#  ▶ print() 공백으로 할 경우 줄바꿈 효과

# %%
print("재미있나요?")
# Out:
# 재미있나요?

# %%
# ,를 사용하여 나열하는 방법으로 한줄에 여러 값 출력 가능
print("출력1", "출력2", 3.45, 5)

# 줄 바꿈 효과 보기
print("줄 바꿈 -----")
print()
print("줄 바꿈 -----")
# Out:
# 출력1 출력2 3.45 5
# 줄 바꿈 -----
#
# 줄 바꿈 -----

# %% [markdown]
# ▶ sep (separation) 옵션
#
# > 문자열 사이에 출력될 글자를 지정 (구분자)

# %%
print('문자열','사이에','출력될','글자를','지정', sep='/')
# Out:
# 문자열/사이에/출력될/글자를/지정

# %% [markdown]
# ▶ end 옵션
#
# > 뒤의 출력값과 이어서 출력
# >
# > sep과 비슷한 구분자를 이용할 수 있다

# %%
print("겨울이 가면", end=' ')
print("봄이 온다")
# Out:
# 겨울이 가면 봄이 온다

# %%
print("벚꽃이 피면", end='/')
print("중간시험이 온다")
# Out:
# 벚꽃이 피면/중간시험이 온다

# %% [markdown]
# ▶ 문자열 포맷
#
# > 다양한 문자열 출력을 위해서 사용
# >
# > 문장 속에 변수를 포함시키는 여러가지 방법들
#
#  **% 기호 사용하기**
#
#  * "문자열" % 값
#
#  * 문자열 부분에 어느 값이 들어가는지 지정(표시)
#
#  > %s - 문자열
#  > %d - 정수
#  > %f - 실수
#
#  ```
#  print("안녕하세요 %s" % ("여러분"))
#  ```
#
#
#
# **{  }+format 사용하기**
#
# * 문장 내 괄호를 넣고, 괄호 속에 출력하려는 값 넣어주기
#
# * 순서대로 중괄호에 들어감
#
#     ```
# print("오늘의 음료는 {},{} 입니다".format(beverage1, beverage2))
# ```
#
# **f-string 사용하기**
#
# * 문자열 앞에 f를 붙이고 문장 내 중괄호에 출력하려는 값 적기
# ```
# print(f"오늘의 음료는 {beverage1},{beverage2} 입니다")
# ```

# %%
beverage1 = '아메리카노'
beverage2 = '딸기라떼'

print("{} 나왔습니다. 가격은 {}원 입니다.".format(beverage1,4500))
# Out:
# 아메리카노 나왔습니다. 가격은 4500원 입니다.

# %%
print(f"오늘의 음료는 {beverage1},{beverage2} 입니다")
# Out:
# 오늘의 음료는 아메리카노,딸기라떼 입니다

# %% [markdown]
# ## 3. 입력 (input 함수)
# ▶ **사용자로부터 값을 입력받음** <br>
# ▶ 기본적으로 입력받은 값은 **문자열로 취급**

# %%
input_values = input("값을 입력하세요: ")
print(type(input_values))
# Out:
# 값을 입력하세요: 4.5
# <class 'str'>

# %%
# 직접해보기 3 - 입력 받은 숫자와 3을 더하기

input_int = input("아무 정수 하나 입력해보기: ")
print("당신의 결과는!: ", int(input_int) + 3)
# Out:
# 아무 정수 하나 입력해보기: 4
# 당신의 결과는!:  7

# %% [markdown]
# ## 4. 주석(comment)
# ▶ **프로그램 진행에 영향을 주지 않는 코드** <br>
#
# ▶ 프로그램 **설명**을 위해 사용 <br>
#
# ▶ **프로그램 크기가 커질수록 반드시 필요함**
# > * 주석처리하고싶은 부분 **앞에 # 붙이기**
# > * 여러줄 주석처리의 경우 ' ' ' 혹은 " " " 로 앞 뒤 감싸기

# %%
# print("이건 주석이라 출력안됩니다.")

"""
print("이것도 주석이라서")
print("출력 안됩니다.")
"""

print("이건 출력됩니다")
# Out:
# 이건 출력됩니다
